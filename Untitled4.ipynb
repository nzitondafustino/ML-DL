# %%
import numpy as np

# %%
np.save('test.npy',np.array([[[1,3,4],[4,6,7],[6,7,8]],[[1,3,4],[4,6,7],[6,7,8]],[[1,3,4],[4,6,7],[6,7,8]],[[1,3,4],[4,6,7],[6,7,8]]]),allow_pickle=True)

# %%
a = np.vstack(np.load('test.npy',allow_pickle=True,mmap_mode='r'))

# %%
a
# Out:
# array([[1, 3, 4],
#        [4, 6, 7],
#        [6, 7, 8],
#        [1, 3, 4],
#        [4, 6, 7],
#        [6, 7, 8],
#        [1, 3, 4],
#        [4, 6, 7],
#        [6, 7, 8],
#        [1, 3, 4],
#        [4, 6, 7],
#        [6, 7, 8]])

# %%
np.memmap('test.npy', dtype='float32', mode='r',shape=(1))
# Out:
# memmap([2.2366853e+08], dtype=float32)

# %%
for i in range(9,-1,-1):
  print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0
