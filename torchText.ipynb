# %%
 import torchtext
 from  torch.utils.data import DataLoader

# %%
train_dataset,val_dataset,test_dataset = torchtext.datasets.WikiText103(root='.data', split=('train', 'valid', 'test'))

# %%
train_loader = DataLoader(train_dataset,batch_size=10)

# %%
for x in train_loader:
  print(len(x[0]))
  print(len(x[1]))
  print(len(x[2]))
  break
# Out:
# 1135
# 2
# 16
