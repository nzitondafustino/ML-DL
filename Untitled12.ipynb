# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np 
import os
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 4.1.2

# %%
# !unzip /content/hw04_for_students.zip

# %%
folder = input("Enter a name of folder: ")

imageList = os.listdir("/content/samples_for_students/" + folder)

for imname in imageList:
    if ".png" in imname:
        print("/content/samples_for_students/" + folder + "/" +imname)
        img = cv2.imread(imname)
        img = plt.imread("/content/samples_for_students/" + folder + "/" +imname)
        cv2.waitKey()
        # cv2.imshow(imname,img)
# Out:
# Enter a name of folder: set1
# /content/samples_for_students/set1/diamondhead-01.png
# /content/samples_for_students/set1/diamondhead-02.png
# /content/samples_for_students/set1/diamondhead-00.png
