# %%
asr_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1966dc33c7c1> in <module>()
# ----> 1 asr_model
#
# NameError: name 'asr_model' is not defined
