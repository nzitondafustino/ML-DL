# %%
# !pip install torch
# !pip install hyperpyyaml

# %%
import torch
from hyperpyyaml import load_hyperpyyaml
import torch.nn  as nn

# %%
my_hyperparams = """

in_features: 20
ou_pout: 10
layer1: !new:torch.nn.Linear
  in_features: !ref <in_features>//2
  out_features: !ref <ou_pout>
relu: !new:torch.nn.ReLU
  inplace: True
model: !new:torch.nn.Sequential
  - !ref <layer1>
  - !ref <relu>
"""

hparams = load_hyperpyyaml(my_hyperparams)
model = hparams["model"]
print(model)
model.modules
# Out:
# Sequential(
#   (0): Linear(in_features=10, out_features=10, bias=True)
#   (1): ReLU(inplace=True)
# )
# <bound method Module.modules of Sequential(
#   (0): Linear(in_features=10, out_features=10, bias=True)
#   (1): ReLU(inplace=True)
# )>

# %%
out = model(data)

# %%
out
# Out:
# tensor([[0.5369, 0.3258, 0.2553, 0.1283, 0.1402, 0.0000, 0.0000, 0.3183, 0.0000,
#          0.0000],
#         [0.2161, 0.1640, 0.0000, 0.0000, 0.0000, 0.3740, 0.0000, 0.1042, 0.0317,
#          0.0000],
#         [0.2504, 0.1209, 0.0646, 0.1070, 0.1104, 0.0000, 0.0000, 0.0396, 0.0000,
#          0.0000],
#         [0.3524, 0.1410, 0.0000, 0.0000, 0.2690, 0.1601, 0.0000, 0.1587, 0.0000,
#          0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0365, 0.0000, 0.1040, 0.0000, 0.0000, 0.1312,
#          0.0000]], grad_fn=<ReluBackward1>)

# %%
# !pip install speechbrain

# %%
from speechbrain.pretrained import EncoderDecoderASR
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-41-25e98fafe433> in <module>()
# ----> 1 from speechbrain.pretrained import EncoderDecoderASR
#
# /usr/local/lib/python3.7/dist-packages/speechbrain/__init__.py in <module>()
#       2 """
#       3 import os
# ----> 4 from .core import Stage, Brain, create_experiment_directory, parse_arguments
#       5 from . import alignment  # noqa
#       6 from . import dataio  # noqa
#
# /usr/local/lib/python3.7/dist-packages/speechbrain/core.py in <module>()
#      31 from torch.nn.parallel import DistributedDataParallel as DDP
#      32 from hyperpyyaml import resolve_references
# ---> 33 from speechbrain.utils.distributed import run_on_main
#      34 from speechbrain.dataio.dataloader import LoopedLoader
#      35 from speechbrain.dataio.dataloader import SaveableDataLoader
#
# ...
