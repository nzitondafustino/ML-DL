# %%
# !git clone https://github.com/KhizarAziz/C3AE_age_estimation_notebook.git
# Out:
# Cloning into 'C3AE_age_estimation_notebook'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 79 (delta 29), reused 12 (delta 4), pack-reused 23
# Unpacking objects: 100% (79/79), done.

# %%
# !ls -l
# Out:
# total 8
# drwxr-xr-x 8 root root 4096 Dec  6 14:04 C3AE_age_estimation_notebook
# drwxr-xr-x 1 root root 4096 Nov 18 14:36 sample_data
